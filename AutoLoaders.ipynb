# %%
f=dbutils.fs.ls('/mnt/demo-datasets/bookstore/')
display(f)

# %%
f=dbutils.fs.ls('/mnt/demo-datasets/bookstore/orders-raw')
display(f)

# %%
(spark.readStream
        .format("cloudFiles")
        .option("cloudFiles.format", "parquet")
        .option("cloudFiles.schemaLocation", "dbfs:/mnt/demo/orders_checkpoint")
        .load("/mnt/demo-datasets/bookstore/orders-raw")
      .writeStream
        .option("checkpointLocation", "dbfs:/mnt/demo/orders_checkpoint")
        .table("orders_updates")
)

# %%
# %sql 
Select * from orders_updates
